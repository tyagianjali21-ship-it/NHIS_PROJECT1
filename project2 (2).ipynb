# %%
print("hello anjai")
# Out:
# hello anjai

# %%
https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy
# Out:
#   Cell In[2], line 1
#     https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy
#                                       ^
# SyntaxError: invalid decimal literal

# %%
link = https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy
print(link)
# Out:
#   Cell In[3], line 1
#     link = https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy
#                                              ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd

# %%
url = "https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy"

# %%
df = pd.read_csv(C:\Users\hp\Downloads)
# Out:
#   Cell In[1], line 1
#     df = pd.read_csv(C:\Users\hp\Downloads)
#                       ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

df = pd.read_csv(url,sep='\t')

# %%
link = https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy
print(link)
# Out:
#   Cell In[9], line 1
#     link = https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy
#                                              ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd

link = "https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy"
df = pd.read_cv(link)
print (df.head())
# Out:
#   Cell In[10], line 4
#     df = pd.read_cv(link)
#     ^
# IndentationError: unexpected indent

# %%
import pandas as pd

link = "https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy"
df = pd.read_csv(link)
print (df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas as pd
#       3 link = "https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy"
# ----> 4 df = pd.read_cv(link)
#       5 print (df.head())
#
# AttributeError: module 'pandas' has no attribute 'read_cv'

# %%
import pandas as pd

link = "https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy"
df = pd.read_csv(link)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[13], line 4
#       1 import pandas as pd
#       3 link = "https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy"
# ----> 4 df = pd.read_csv(link)
#       5 print(df.head())
#
# ...

# %%
# !pip install numpy

# %%
# !pip install matplotlib

# %%
# !pip install panda
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for panda: filename=panda-0.3.1-py3-none-any.whl size=7295 sha256=8036b90c5627297f215cd20233f50c33fe6dc68de11b332f9325f8455f310502
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\53\7c\f7\d3267739bc9dfdfc43724391337c9955e7d5b5830888d735e3
# Successfully built panda
# ...

# %%
# !pip install seaborn

# %%
import numpy as np
import seaborn as sns
import matplotlip.pyplot as plt
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 3
#       1 import numpy as np
#       2 import seaborn as sns
# ----> 3 import matplotlip.pyplot as plt
#       4 import panda as pd
#
# ModuleNotFoundError: No module named 'matplotlip'

# %%
# !pip install matplotlib

# %%
import matplotlib as plt

# %%
df = pd.read_csv(https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy)
# Out:
#   Cell In[28], line 1
#     df = pd.read_csv(https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy)
#                                                        ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd

file_id = "1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj"
url = f"https://google.com{file_id}"

df = pd.read_csv(url)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1338, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1337 """Send a complete request to the server."""
# -> 1338 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1384, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1383     body = _encode(body, 'body')
# -> 1384 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
df = pd.read_csv(industry)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df = pd.read_csv(industry)
#
# NameError: name 'industry' is not defined

# %%
df = pd.read_csv(https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy)
# Out:
#   Cell In[31], line 1
#     df = pd.read_csv(https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy)
#                                                        ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd

df = pd.read_csv(https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy)
# Out:
#   Cell In[32], line 3
#     df = pd.read_csv(https://drive.google.com/open?id=1_AN0a6oFFUoWUWVTfyO2ATyxkgLw6Hjj&usp=drive_copy)
#                                                        ^
# SyntaxError: invalid decimal literal

# %%
import pandas as pd

df = pd.read_csv(r'industry 1')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r'industry 1')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
import pandas as pd

df = pd.read_csv(C:\Users\hp\Downloads)
# Out:
#   Cell In[2], line 3
#     df = pd.read_csv(C:\Users\hp\Downloads)
#                       ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv(r'C:\Users\hp\Downloads\industry.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\hp\Downloads\industry.csv')
#
# NameError: name 'pd' is not defined

# %%
import panda as pd

df = pd.read_csv(r'C:\Users\hp\Downloads\industry.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import panda as pd
#       3 df = pd.read_csv(r'C:\Users\hp\Downloads\industry.csv')
#
# File ~\anaconda3\Lib\site-packages\panda\__init__.py:1
# ----> 1 from request import PandaRequest
#       2 from models import Video, Cloud, Encoding, Profile, Notifications, PandaDict
#       3 from models import GroupRetriever, SingleRetriever
#
# ModuleNotFoundError: No module named 'request'

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\hp\Downloads\industry.csv")

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r"C:\Users\hp\Downloads\industry.csv")
#       5 print(df.head())
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\hp\Downloads\industry(1).csv", encoding = unicode_escape)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv(r"C:\Users\hp\Downloads\industry(1).csv", encoding = unicode_escape)
#       5 print(df.head())
#
# NameError: name 'unicode_escape' is not defined

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hp\Downloads\industry(1).csv") 
urlretrieve(url, save_path)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv(r"C:\Users\hp\Downloads\industry(1).csv")
#       3 urlretrieve(url, save_path)
#       4 print(df.head())
#
# ...

# %%
C:\Users\hp\Downloads\industry(1).csv
# Out:
#   Cell In[13], line 1
#     C:\Users\hp\Downloads\industry(1).csv
#        ^
# SyntaxError: unexpected character after line continuation character

# %%
import pandas as pd

df = pd.read_csv(r"Downloads/INDUSTRY (1).csv")

print(df.head())
